# %% [markdown]
# # Математический тест Авито

# %%
import pandas as pd
from scipy.stats import chisquare

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3 броска, 8 граней, значения из списка

throws = 3
N = 8
values = [1, 5, 10, 15, 20, 25, 30, 45]

# %%
third_throw_mo = sum(values) / N

# (1 + 5 + 10 + 15 + 20 + 25 + 30 + 45) / 8


second_third_throw_mo = sum([i if i > third_throw_mo else third_throw_mo for i in values]) / N

# (4/8) * 18.875 + (20 + 25 + 30 + 45) / 8


first_second_third_throw = sum([i if i > second_third_throw_mo else second_throw_mo for i in values]) / N

# (5/8) * 24.4375 + (25 + 30 + 45) / 8
first_second_third_throw
# Out:
# 27.7734375

# %%
# Общий случай - 2 броска, 2N граней, значения k

second_throw_mo = sum(k) / 2N

first_second_throw = sum([i if i > second_throw_mo else second_throw_mo for i in k]) / 2N

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### b)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### b)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### b)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 типа перестановок:
# 1) Шаг вправо на одно поле (N-1 шагов из-за исходной позиции)
# 2) Шаг вниз на одно поле (N-1)
#
# Всего перестановок n = N - 1 + N - 1 = 2N - 2
#
# Всего комбинаций = **(2N - 2)! / (N - 1)! * (N - 1)!**
#
# Для поля 8x8 - 3432 комбинаций

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Сравниваем с равномерным частотным распределением: 8, 8, считаем расстояние Пирсона (статистика хи-квадрат)

((14 - 8) ** 2) / 8 + ((2 - 8) ** 2) / 8
# Out:
# 9.0

# %%
chisquare([14, 2]) # Нулевая гипотеза отвергается, выбирает неслучайно
# Out:
# Power_divergenceResult(statistic=9.0, pvalue=0.0026997960632601883)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Отклонение от прогноза в последний месяц очень похоже на отклонение в ноябре-декабре 2017, возможная причина - в прогнозе не учтена сезонность, можно сравнить прогнозы прошлых лет за идентичные периоды.
# 2. Просмотреть данные по разбивкам (Гео, платформа, пол, возраст, категория, страница), напр. метрики: количество активных юзеров, повторные покупки, конверсия, средний чек.
#
# Как вариант: по каждой точке считаем разность между фактом и прогнозом, строим дов.интервал для плановых значений на основе std ошибок, если факт значение выходит за дов. интервал - считаем аномалией (также возможно применения стат.тестов или бутстрапа).
